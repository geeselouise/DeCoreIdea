# %%
from pinterest import PinterestImageScraper

# %%
iscrape = PinterestImageScraper()

# %%
download = iscrape.make_ready('bohemian interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('shabby chic interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|                                                                                           | 0/38 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('eclectic interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|                                                                                           | 0/61 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('modern interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/82 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/82 [00:00<?, ?it/s]
# [+] saving image urls ...
# [+] Total 822 files available to download.
#   0%|                                                                                           | 0/82 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/82 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/82 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/82 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('contemporary interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('transitional interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/109 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/109 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/109 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/109 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/109 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/109 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('art deco interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/134 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/134 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/134 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/134 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/134 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/134 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('traditional interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/152 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/152 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/152 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/152 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/152 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/152 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('rustic interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('industrial interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/195 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/195 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/195 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/195 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/195 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/195 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('scandinavian interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('french country interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/243 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/243 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/243 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/243 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/243 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/243 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('mid century modern interior design style')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/268 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/268 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/268 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/268 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/268 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/268 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('mid century modern furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
#   0%|                                                                                           | 0/78 [00:00<?, ?it/s]
# [+] saving image urls ...
# [+] Total 787 files available to download.
#   0%|                                                                                           | 0/78 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/78 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/78 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/78 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/78 [00:00<?, ?it/s]
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('modern furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/68 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/68 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/68 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/68 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/68 [00:00<?, ?it/s]
# [+] saving image urls ...
# [+] Total 683 files available to download.
#   0%|                                                                                           | 0/68 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('traditional furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|                                                                                           | 0/22 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('bohemian furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('shabby chic')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# ...
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|                                                                                           | 0/33 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('industrial furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
#   0%|                                                                                           | 0/58 [00:00<?, ?it/s]
# [+] saving image urls ...
# [+] Total 581 files available to download.
#   0%|                                                                                           | 0/58 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/58 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/58 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/58 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/58 [00:00<?, ?it/s]
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('transitional furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                           | 0/73 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/73 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/73 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/73 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/73 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/73 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('traditional furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#
#
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('scandinavian furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('art deco furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/147 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/147 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/147 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/147 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/147 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/147 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('eclectic furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/167 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/167 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/167 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/167 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/167 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/167 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...

# %%
download = iscrape.make_ready('rustic furniture')
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# ...
#   0%|                                                                                          | 0/191 [00:00<?, ?it/s]
#
#   0%|                                                                                          | 0/191 [00:00<?, ?it/s]
#
#
#   0%|                                                                                          | 0/191 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                          | 0/191 [00:00<?, ?it/s]
#
#
#
#
#   0%|                                                                                          | 0/191 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                          | 0/191 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...
